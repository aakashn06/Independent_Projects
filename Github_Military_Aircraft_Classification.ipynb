# %%
# !pip install kaggle

# %%
import os
os.environ['KAGGLE_API_TOKEN'] = "token"

# %%
# !kaggle competitions list
# Out:
# ref                                                                              deadline             category                reward  teamCount  userHasEntered
# -------------------------------------------------------------------------------  -------------------  ---------------  -------------  ---------  --------------
# https://www.kaggle.com/competitions/ai-mathematical-olympiad-progress-prize-3    2026-04-15 23:59:00  Featured         2,207,152 Usd       2453           False
# https://www.kaggle.com/competitions/vesuvius-challenge-surface-detection         2026-02-27 23:59:00  Research           200,000 Usd       1390           False
# https://www.kaggle.com/competitions/stanford-rna-3d-folding-2                    2026-03-25 23:59:00  Featured           100,000 Usd       1077           False
# https://www.kaggle.com/competitions/med-gemma-impact-challenge                   2026-02-24 23:59:00  Featured           100,000 Usd        299           False
# ...

# %%
# !export KAGGLE_API_TOKEN=token

# %%
# !mkdir -p /root/.kaggle

# %%
import json

kaggle_config = {
    "username": "username",
    "key": "key"
}

with open("/root/.kaggle/kaggle.json", "w") as f:
    json.dump(kaggle_config, f)

# %%
# !ls -la /root/.kaggle
# Out:
# total 16
# drwxr-xr-x 2 root root 4096 Feb 23 02:37 .
# drwx------ 1 root root 4096 Feb 23 02:37 ..
# -rw------- 1 root root   73 Feb 23 02:45 kaggle.json

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("a2015003713/militaryaircraftdetectiondataset")

print("Path to dataset files:", path)
# Out:
# ...
# Resuming download from 7952400384 bytes (3890876164 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/a2015003713/militaryaircraftdetectiondataset?dataset_version_number=98 (7952400384/11843276548) bytes left.
# 100%|██████████| 11.0G/11.0G [02:48<00:00, 23.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/a2015003713/militaryaircraftdetectiondataset/versions/98

# %%
# Explore dataset
data_path = "/kaggle/input/militaryaircraftdetectiondataset"
os.listdir(data_path)

# %%
# Print some examples
import pandas as pd
df = pd.read_csv("/kaggle/input/militaryaircraftdetectiondataset/labels_with_split.csv")
print(df.head())

# %%
# There are multiple duplicate images in the dataset. Keep only first object per image for classification.
image_labels = df.groupby('filename').first().reset_index()
